# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import _pickle as pickle
import numpy as np
from scipy.stats import halfnorm

# %%
with open("profile_data.pkl",'rb') as fp:
    df = pickle.load(fp)

# %%
df
# Out:
#                                                    Bios  Movies  TV  Religion  \
# 0     Typical communicator. Subtly charming web advo...       0   6         4
# 1     Introvert. Friendly beer guru. Bacon fanatic. ...       0   3         5
# 2     Friend of animals everywhere. Passionate zombi...       2   5         6
# 3     Webaholic. Pop culture ninja. Wannabe organize...       4   2         9
# 4     Zombie buff. Troublemaker. Social media ninja....       3   0         9
# ...                                                 ...     ...  ..       ...
# 8290  Wannabe analyst. General food enthusiast. Musi...       1   2         1
# 8291  Friendly pop cultureaholic. Analyst. Gamer. Am...       1   4         8
# 8292  Alcohol nerd. Award-winning music fan. Profess...       2   6         3
# 8293  Organizer. Introvert. Twitter junkie. Certifie...       1   8         2
# 8294  Unable to type with boxing gloves on. Devoted ...       0   7         4
#
#       Music  Sports  Travelling  Foodie  Books  Politics  Finance  Coding
# 0         2       2           2       5      2         3        5       5
# 1         5       7           3       7      5         4        2       0
# 2         4       3           0       3      1         8        7       8
# 3         6       9           5       0      5         1        5       2
# 4         6       7           1       0      2         3        5       6
# ...     ...     ...         ...     ...    ...       ...      ...     ...
# 8290      1       1           5       6      2         7        2       9
# 8291      2       8           5       5      3         1        5       1
# 8292      0       0           2       7      1         1        9       0
# 8293      2       9           6       1      8         7        0       8
# 8294      3       4           7       2      7         3        0       4
#
# [8295 rows x 12 columns]

# %%
# Using only Bios
# Removing the numerical data
df = df[['Bios']]

# %%
df
# Out:
#                                                    Bios
# 0     Typical communicator. Subtly charming web advo...
# 1     Introvert. Friendly beer guru. Bacon fanatic. ...
# 2     Friend of animals everywhere. Passionate zombi...
# 3     Webaholic. Pop culture ninja. Wannabe organize...
# 4     Zombie buff. Troublemaker. Social media ninja....
# ...                                                 ...
# 8290  Wannabe analyst. General food enthusiast. Musi...
# 8291  Friendly pop cultureaholic. Analyst. Gamer. Am...
# 8292  Alcohol nerd. Award-winning music fan. Profess...
# 8293  Organizer. Introvert. Twitter junkie. Certifie...
# 8294  Unable to type with boxing gloves on. Devoted ...
#
# [8295 rows x 1 columns]

# %% [markdown]
# ### Creating Lists for the Categories
# Here, we are specifying the categories into subcategories and allocating the probability of being an interest to each subcategory of interest

# %%
#Probability distribution
p = {}

# Movie Genres
movies = ['Adventure',
          'Action',
          'Drama',
          'Comedy',
          'Thriller',
          'Horror',
          'RomCom',
          'Musical',
          'Documentary']

p['Movies'] = [0.26,
               0.21,
               0.16,
               0.14,
               0.09,
               0.06,
               0.04,
               0.01, 
               0.03]

# TV Genres
tv = ['Comedy',
      'Drama',
      'Action/Adventure',
      'Suspense/Thriller',
      'Documentaries',
      'Crime/Mystery',
      'News',
      'SciFi',
      'History']

p['TV'] = [0.25,
           0.21,
           0.17,
           0.16,
           0.09,
           0.08,
           0.03,
           0.02,
           0.01]

# Religions (could potentially create a spectrum)
religion = ['Catholic',
            'Christian',
            'Jewish',
            'Muslim',
            'Hindu',
            'Buddhist',
            'Spiritual',
            'Other',
            'Agnostic',
            'Atheist']

p['Religion'] = [0.07,
                 0.13,
                 0.01,
                 0.19,
                 0.24,
                 0.05,
                 0.10,
                 0.09,
                 0.07,
                 0.05]

# Music
music = ['Rock',
         'HipHop',
         'Romantic',
         'Pop',
         'Country',
         'EDM',
         'Jazz',
         'Classical',
         ]

p['Music'] = [0.25,
              0.19,
              0.16,
              0.14,
              0.10,
              0.06,
              0.04,
              0.03,
              0.02,
              0.01,]

# Sports
sports = [
          'Cricket',
          'Chess',
          'Badminton'
          'Football',
          'Baseball',
          'Basketball',
          'Hockey',
          'Soccer',
          'Other']

p['Sports'] = [0.29,
               0.24,
               0.23, 
               0.13,
               0.04,
               0.03,
               0.02,
               0.02]

# Politics (could also put on a spectrum)
politics = ['Liberal',
            'Progressive',
            'Centrist',
            'Moderate',
            'Conservative']

p['Politics'] = [0.26,
                 0.11,
                 0.11,
                 0.15,
                 0.37]

# Social Media
social = ['Facebook',
          'Youtube',
          'Twitter',
          'Reddit',
          'Instagram',
          'Pinterest',
          'LinkedIn',
          'SnapChat',
          'TikTok']

p['Social Media'] = [0.36,
                     0.27,
                     0.11,
                     0.09,
                     0.05,
                     0.03,
                     0.03,
                     0.03,
                     0.03]

# Programming
programming = [
          'Python',
          'Java',
          'JavaScript',
          'C++',
          'C#',
          'Swift',
          'Go'
         ]

p['programming'] = [
                    0.23,
                    0.20,
                    0.18,
                    0.15,
                    0.12,
                    0.10,
                    0.02
                   ]

#travelling
travelling = [
            'Treking',
            'Adventure',
            'Long Trips',
            'Short journeys'
             ]

p['travelling'] = [
                 0.35,
                 0.33,
                 0.21,
                 0.11
                  ]


# Age (generating random numbers based on half normal distribution)
age = halfnorm.rvs(loc=18,scale=8, size=df.shape[0]).astype(int)

# Lists of Names and the list of the lists
categories = [movies, religion, music, politics, social, sports, age, programming, travelling]

names = ['Movies','Religion', 'Music', 'Politics', 'Social Media', 'Sports', 'Age', 'Programming', 'Traveller']

combined = dict(zip(names, categories))

# %%
combined
# Out:
# {'Movies': ['Adventure',
#   'Action',
#   'Drama',
#   'Comedy',
#   'Thriller',
#   'Horror',
#   'RomCom',
#   'Musical',
#   'Documentary'],
#  'Religion': ['Catholic',
#   'Christian',
#   'Jewish',
#   'Muslim',
#   'Hindu',
#   'Buddhist',
#   'Spiritual',
#   'Other',
#   'Agnostic',
#   'Atheist'],
#  'Music': ['Rock',
#   'HipHop',
#   'Romantic',
#   'Pop',
#   'Country',
#   'EDM',
#   'Jazz',
#   'Classical'],
#  'Politics': ['Liberal',
#   'Progressive',
#   'Centrist',
#   'Moderate',
#   'Conservative'],
#  'Social Media': ['Facebook',
#   'Youtube',
#   'Twitter',
#   'Reddit',
#   'Instagram',
#   'Pinterest',
#   'LinkedIn',
#   'SnapChat',
#   'TikTok'],
#  'Sports': ['Cricket',
#   'Chess',
#   'BadmintonFootball',
#   'Baseball',
#   'Basketball',
#   'Hockey',
#   'Soccer',
#   'Other'],
#  'Age': array([18, 18, 22, ..., 22, 31, 22]),
#  'Programming': ['Python', 'Java', 'JavaScript', 'C++', 'C#', 'Swift', 'Go'],
#  'Traveller': ['Treking', 'Adventure', 'Long Trips', 'Short journeys']}

# %% [markdown]
# ### Assigning random values to each subcategory of a category
# Looping through the combined df, we will assign randomly generated value from each subcategory to the repsective category

# %%
# Looping through and assigning random values
for name, cats in combined.items():
    if name in ['Religion', 'Politics']:
        # Picking only 1 from the list
        df[name] = np.random.choice(cats, df.shape[0], p=p[name])
        
    elif name == 'Age':
        # Generating random ages based on a normal distribution
        df[name] = cats
    else:
        # Picking 3 from the list 
        try:
            df[name] = list(np.random.choice(cats, size=(df.shape[0],1,3), p=p[name]))
        except:
            df[name] = list(np.random.choice(cats, size=(df.shape[0],1,3)))
        
        df[name] = df[name].apply(lambda x: list(set(x[0].tolist())))
# Out:
# C:\Users\aksha\AppData\Local\Temp/ipykernel_10272/3693085958.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[name] = list(np.random.choice(cats, size=(df.shape[0],1,3), p=p[name]))
# C:\Users\aksha\AppData\Local\Temp/ipykernel_10272/3693085958.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[name] = df[name].apply(lambda x: list(set(x[0].tolist())))
# C:\Users\aksha\AppData\Local\Temp/ipykernel_10272/3693085958.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[name] = np.random.choice(cats, df.shape[0], p=p[name])
# C:\Users\aksha\AppData\Local\Temp/ipykernel_10272/3693085958.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[name] = list(np.random.choice(cats, size=(df.shape[0],1,3)))
# C:\Users\aksha\AppData\Local\Temp/ipykernel_10272/3693085958.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[name] = cats

# %%
df
# Out:
#                                                    Bios  \
# 0     Typical communicator. Subtly charming web advo...
# 1     Introvert. Friendly beer guru. Bacon fanatic. ...
# 2     Friend of animals everywhere. Passionate zombi...
# 3     Webaholic. Pop culture ninja. Wannabe organize...
# 4     Zombie buff. Troublemaker. Social media ninja....
# ...                                                 ...
# 8290  Wannabe analyst. General food enthusiast. Musi...
# 8291  Friendly pop cultureaholic. Analyst. Gamer. Am...
# 8292  Alcohol nerd. Award-winning music fan. Profess...
# 8293  Organizer. Introvert. Twitter junkie. Certifie...
# 8294  Unable to type with boxing gloves on. Devoted ...
#
#                            Movies   Religion                        Music  \
# 0     [Adventure, Action, Comedy]  Christian       [EDM, Classical, Jazz]
# 1         [Comedy, Action, Drama]   Agnostic          [HipHop, EDM, Jazz]
# 2      [Adventure, Action, Drama]      Other        [Romantic, EDM, Rock]
# 3      [Comedy, Thriller, Action]      Hindu     [HipHop, Classical, Pop]
# 4       [Thriller, Action, Drama]  Christian  [Romantic, Classical, Jazz]
# ...                           ...        ...                          ...
# 8290          [Adventure, Comedy]    Atheist            [HipHop, Country]
# 8291      [Horror, Action, Drama]   Catholic          [EDM, Country, Pop]
# 8292           [Adventure, Drama]      Hindu     [Romantic, Country, Pop]
# 8293          [Adventure, Action]    Atheist     [HipHop, EDM, Classical]
# 8294   [Action, Comedy, Thriller]     Muslim         [EDM, Romantic, Pop]
#
#           Politics                   Social Media  \
# 0          Liberal              [Reddit, Youtube]
# 1      Progressive    [Youtube, Facebook, Reddit]
# 2          Liberal  [LinkedIn, Youtube, Facebook]
# 3     Conservative           [Youtube, Pinterest]
# 4     Conservative    [LinkedIn, Reddit, Twitter]
# ...            ...                            ...
# 8290   Progressive            [Youtube, Facebook]
# 8291       Liberal            [Youtube, Facebook]
# 8292  Conservative                      [Youtube]
# 8293  Conservative            [Facebook, Twitter]
# 8294  Conservative            [Youtube, Facebook]
#
#                                         Sports  Age  \
# 0                 [Cricket, Chess, Basketball]   18
# 1          [Cricket, Chess, BadmintonFootball]   18
# 2          [Cricket, BadmintonFootball, Chess]   22
# 3          [Cricket, BadmintonFootball, Other]   24
# 4     [Cricket, BadmintonFootball, Basketball]   25
# ...                                        ...  ...
# 8290              [Cricket, BadmintonFootball]   26
# 8291                          [Chess, Cricket]   18
# 8292       [Cricket, BadmintonFootball, Chess]   22
# 8293                          [Chess, Cricket]   31
# 8294                                 [Cricket]   22
#
#                       Programming                                Traveller
# 0       [C++, JavaScript, Python]  [Adventure, Long Trips, Short journeys]
# 1               [C++, Python, Go]                [Treking, Short journeys]
# 2             [Swift, Python, Go]                [Treking, Short journeys]
# 3            [C++, Swift, Python]             [Long Trips, Short journeys]
# 4         [Java, C++, JavaScript]             [Long Trips, Short journeys]
# ...                           ...                                      ...
# 8290             [JavaScript, Go]             [Long Trips, Short journeys]
# 8291          [Swift, C#, Python]                  [Adventure, Long Trips]
# 8292   [Java, JavaScript, Python]         [Adventure, Treking, Long Trips]
# 8293                   [Java, C#]              [Adventure, Short journeys]
# 8294  [JavaScript, Swift, Python]                         [Short journeys]
#
# [8295 rows x 10 columns]

# %% [markdown]
# ### Categorizing the religion and poilitics

# %%
df['Religion'] = pd.Categorical(df.Religion, ordered=True,
                                categories=['Catholic',
                                            'Christian',
                                            'Jewish',
                                            'Muslim',
                                            'Hindu',
                                            'Buddhist',
                                            'Spiritual',
                                            'Other',
                                            'Agnostic',
                                            'Atheist'])

df['Politics'] = pd.Categorical(df.Politics, ordered=True,
                                categories=['Liberal',
                                            'Progressive',
                                            'Centrist',
                                            'Moderate',
                                            'Conservative'])
# Out:
# C:\Users\aksha\AppData\Local\Temp/ipykernel_10272/1357384825.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Religion'] = pd.Categorical(df.Religion, ordered=True,
# C:\Users\aksha\AppData\Local\Temp/ipykernel_10272/1357384825.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Politics'] = pd.Categorical(df.Politics, ordered=True,

# %%
df
# Out:
#                                                    Bios  \
# 0     Typical communicator. Subtly charming web advo...
# 1     Introvert. Friendly beer guru. Bacon fanatic. ...
# 2     Friend of animals everywhere. Passionate zombi...
# 3     Webaholic. Pop culture ninja. Wannabe organize...
# 4     Zombie buff. Troublemaker. Social media ninja....
# ...                                                 ...
# 8290  Wannabe analyst. General food enthusiast. Musi...
# 8291  Friendly pop cultureaholic. Analyst. Gamer. Am...
# 8292  Alcohol nerd. Award-winning music fan. Profess...
# 8293  Organizer. Introvert. Twitter junkie. Certifie...
# 8294  Unable to type with boxing gloves on. Devoted ...
#
#                            Movies   Religion                        Music  \
# 0     [Adventure, Action, Comedy]  Christian       [EDM, Classical, Jazz]
# 1         [Comedy, Action, Drama]   Agnostic          [HipHop, EDM, Jazz]
# 2      [Adventure, Action, Drama]      Other        [Romantic, EDM, Rock]
# 3      [Comedy, Thriller, Action]      Hindu     [HipHop, Classical, Pop]
# 4       [Thriller, Action, Drama]  Christian  [Romantic, Classical, Jazz]
# ...                           ...        ...                          ...
# 8290          [Adventure, Comedy]    Atheist            [HipHop, Country]
# 8291      [Horror, Action, Drama]   Catholic          [EDM, Country, Pop]
# 8292           [Adventure, Drama]      Hindu     [Romantic, Country, Pop]
# 8293          [Adventure, Action]    Atheist     [HipHop, EDM, Classical]
# 8294   [Action, Comedy, Thriller]     Muslim         [EDM, Romantic, Pop]
#
#           Politics                   Social Media  \
# 0          Liberal              [Reddit, Youtube]
# 1      Progressive    [Youtube, Facebook, Reddit]
# 2          Liberal  [LinkedIn, Youtube, Facebook]
# 3     Conservative           [Youtube, Pinterest]
# 4     Conservative    [LinkedIn, Reddit, Twitter]
# ...            ...                            ...
# 8290   Progressive            [Youtube, Facebook]
# 8291       Liberal            [Youtube, Facebook]
# 8292  Conservative                      [Youtube]
# 8293  Conservative            [Facebook, Twitter]
# 8294  Conservative            [Youtube, Facebook]
#
#                                         Sports  Age  \
# 0                 [Cricket, Chess, Basketball]   18
# 1          [Cricket, Chess, BadmintonFootball]   18
# 2          [Cricket, BadmintonFootball, Chess]   22
# 3          [Cricket, BadmintonFootball, Other]   24
# 4     [Cricket, BadmintonFootball, Basketball]   25
# ...                                        ...  ...
# 8290              [Cricket, BadmintonFootball]   26
# 8291                          [Chess, Cricket]   18
# 8292       [Cricket, BadmintonFootball, Chess]   22
# 8293                          [Chess, Cricket]   31
# 8294                                 [Cricket]   22
#
#                       Programming                                Traveller
# 0       [C++, JavaScript, Python]  [Adventure, Long Trips, Short journeys]
# 1               [C++, Python, Go]                [Treking, Short journeys]
# 2             [Swift, Python, Go]                [Treking, Short journeys]
# 3            [C++, Swift, Python]             [Long Trips, Short journeys]
# 4         [Java, C++, JavaScript]             [Long Trips, Short journeys]
# ...                           ...                                      ...
# 8290             [JavaScript, Go]             [Long Trips, Short journeys]
# 8291          [Swift, C#, Python]                  [Adventure, Long Trips]
# 8292   [Java, JavaScript, Python]         [Adventure, Treking, Long Trips]
# 8293                   [Java, C#]              [Adventure, Short journeys]
# 8294  [JavaScript, Swift, Python]                         [Short journeys]
#
# [8295 rows x 10 columns]

# %% [markdown]
# ### Saving and exporting the pickle file

# %%
with open("refined_profiles.pkl",'wb') as fp:
    pickle.dump(df, fp)
